# %%
from random import *
from tkinter import*
def afficher(M):
    "Affiche une matrice en respectant les alignements par colonnes"
    w=[max([len(str(M[i][j])) for i in range(len(M))]) for j in range(len(M[0]))]
    for i in range(len(M)):
        for j in range(len(M[0])):
            print("%*s" %(w[j],str(M[i][j])), end= ' ')
        print()    

def voisins(n, i, j):
    """Dans une grille n x n, indices (ligne, colonne) des voisins 
    dans la grille d'un sommet (i,j) de la grille"""
    return [(a,b) for (a, b) in [(i,j+1),(i,j-1),(i+1,j),(i-1,j),(i+1,j+1),(i+1,j-1),(i-1,j+1),(i-1,j-1)] if a in range(n) and b in range(n)]

def bomb(L,n,l,c):
    vbomb=voisins(n,l,c)#liste des voisions d'une bombe
    print(vbomb)
    vbomb_len=len(vbomb)
    for i in range(len(L)):
        for j in range(len(L[0])):
            for (a, b) in vbomb:
                if (a,b)==(i,j): #parcours les coordonées de L et les compare avec celle dans vbomb et si elles sont egale
                    x=L[i][j]    #x =x+1
                    if x!=9:
                        x=x+1
                    L[i][j]=x
         
        
        
        
        
        
n=8 #nombre de case afficher

L=[[],[],[],[],[],[],[],[]]
s=0
b=11 #nombre de bombe
for i in range (len(L)):
    for j in range (8):
         L[i].append(0)

for p in range (b):
    l=randrange(8)
    c=randrange(8)
    L[l][c]=9
    bomb(L,n,l,c)
    
afficher(L)








WIDTH=n*10 #chaque case fera 10*10 la taille de la fenetre sera en fonction de n 
HEIGHT=n*10
root=Tk()
unit=50


cnv = Canvas(root, width=unit*n, height=unit*n, background="ivory") 
cnv.pack(padx=10, pady=10, side=LEFT)



def jeu(event):   # quand on cliqe sur une case ça renvoit les coordonées correspondant à la liste L
    print(event.x,event.y)
    y=event.x//50
    x=event.y//50
    print(x,y)
    C=(x,y)
    if L[x][y]!=9:
        x=L[x][y]
        a=(event.x//50)*50
        b=(event.y//50)*50
        cnv.create_text(a+25, b+25, text=x, font="Arial 50 bold")

        
    else:
        print("bombe !")
        for i in range(len(L)):
            for j in range(len(L[0])):
                if L[i][j]==9:
                    a=j*50
                    b=i*50
                    cnv.create_oval((10+a,10+b,a+40,b+40),fill='black',width=1,outline="black") # montre toute les bombe quand on clic sur UNE bombe
                    
        
nbrflag=0
F=[]
O=[]
def flag (event):
    global F
    global nbrflag
    global n
    print(n)
    print(nbrflag)
    y=event.x//50
    x=event.y//50
    a,b=y*50,x*50
    ids=[]
    if nbrflag<n and (a,b) not in F: # le "nbrflag" pour limiter le nombre de drapeau que l'on peux poser au nombre de bombe .
        # et la liste F permet de noté si un flag a déja etait mis à un cet endroit 
        O.append(cnv.create_oval((10+a,10+b,a+40,b+40),fill='red',width=1,outline="red"))#crée l'oval et met son id dans la liste O
        nbrflag=nbrflag+1
        F.append((a,b))
        print(F)
        print(O)
    elif (a,b) in F:
        q=0
        p=True
        while p :
            if (a,b) == F[q]:
                p=False
            else:
                q=q+1
        #q Est l'emplacement dans la liste de l'id de l'oval à supprimer 
        cnv.delete(O[q])
        del O[q]
        del F[q]
        nbrflag=nbrflag-1

            
def interro (event):#double clic droit pour mettre un point d'interrogation
    y=event.x//50
    x=event.y//50
    nbr_clic=0
    a=y*50
    b=x*50
    cnv.create_oval((10+a,10+b,a+40,b+40),fill='green',width=1,outline="green")
    
        


def init(): # initialise les case du jeu.
    for line in range(n):
        for col in range(n):
            A=(unit*col, unit*line)
            B=(unit*(col+1), unit*(line+1))
               
            cnv.create_rectangle(A, B, fill="grey",)
            


cnv.bind("<Button-1>",jeu)
cnv.bind("<Button-3>",flag)
cnv.bind("<Double-Button-3>",interro)


   
                
init()
root.mainloop()
# Out:
# [(5, 1), (6, 0), (4, 0), (6, 1), (4, 1)]
# [(7, 1), (6, 0), (6, 1)]
# [(6, 4), (6, 2), (7, 3), (5, 3), (7, 4), (7, 2), (5, 4), (5, 2)]
# [(1, 1), (2, 0), (0, 0), (2, 1), (0, 1)]
# [(5, 6), (6, 7), (4, 7), (6, 6), (4, 6)]
# [(3, 1), (4, 0), (2, 0), (4, 1), (2, 1)]
# [(6, 1), (7, 0), (5, 0), (7, 1), (5, 1)]
# [(1, 5), (1, 3), (2, 4), (0, 4), (2, 5), (2, 3), (0, 5), (0, 3)]
# [(4, 4), (4, 2), (5, 3), (3, 3), (5, 4), (5, 2), (3, 4), (3, 2)]
# [(5, 6), (6, 7), (4, 7), (6, 6), (4, 6)]
# [(0, 1), (1, 0), (1, 1)]
# 9 2 0 1 1 1 0 0
# 9 2 0 1 9 1 0 0
# 2 2 0 1 1 1 0 0
# 9 1 1 1 1 0 0 0
# 2 2 1 9 1 0 2 2
# 9 2 2 2 2 0 2 9
# 9 3 1 9 1 0 2 2
# 9 2 1 1 1 0 0 0
# 204 10
# 0 4
# 8
# 0
# [(0, 0)]
# [66]
# 8
# 1
# [(0, 0), (50, 0)]
# [66, 67]
# 8
# 2
# [(0, 0), (50, 0), (50, 50)]
# [66, 67, 68]
# 8
# 3
# [(0, 0), (50, 0), (50, 50), (0, 50)]
# [66, 67, 68, 69]
# 8
# 4
# [(0, 0), (50, 0), (50, 50), (0, 50), (0, 100)]
# [66, 67, 68, 69, 70]
# 8
# 5
# [(0, 0), (50, 0), (50, 50), (0, 50), (0, 100), (50, 100)]
# [66, 67, 68, 69, 70, 71]
# 8
# 6
# [(0, 0), (50, 0), (50, 50), (0, 50), (0, 100), (50, 100), (50, 150)]
# [66, 67, 68, 69, 70, 71, 72]
# 8
# 7
# [(0, 0), (50, 0), (50, 50), (0, 50), (0, 100), (50, 100), (50, 150), (0, 150)]
# [66, 67, 68, 69, 70, 71, 72, 73]
# 8
# 8
# 8
# 8
# 6
# 8
# 7
# 6
# 8
# 6
# [(0, 0), (50, 0), (50, 50), (0, 50), (0, 100), (50, 100), (50, 150)]
# [66, 67, 68, 69, 70, 71, 74]
# 8
# 7
# [(0, 0), (50, 0), (50, 50), (0, 50), (0, 100), (50, 100), (50, 150), (0, 150)]
# [66, 67, 68, 69, 70, 71, 74, 75]
# 8
# 8
# 4
# 8
# 7
# 4
# 8
# 6
# [(0, 0), (50, 0), (50, 50), (0, 50), (50, 150), (0, 150), (0, 100)]
# [66, 67, 68, 69, 74, 75, 76]
# 8
# 7
# [(0, 0), (50, 0), (50, 50), (0, 50), (50, 150), (0, 150), (0, 100), (50, 100)]
# [66, 67, 68, 69, 74, 75, 76, 77]
# 8
# 8
# 2
# 8
# 7
# [(0, 0), (50, 0), (0, 50), (50, 150), (0, 150), (0, 100), (50, 100), (50, 50)]
# [66, 67, 69, 74, 75, 76, 77, 78]
# 8
# 8
# 2
# 8
# 7
# [(0, 0), (50, 0), (50, 150), (0, 150), (0, 100), (50, 100), (50, 50), (100, 50)]
# [66, 67, 74, 75, 76, 77, 78, 79]
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 8
# 7
# 6
# 8
# 6
# [(0, 0), (50, 0), (50, 150), (0, 150), (0, 100), (50, 100), (100, 0)]
# [66, 67, 74, 75, 76, 77, 80]
# 8
# 7
# [(0, 0), (50, 0), (50, 150), (0, 150), (0, 100), (50, 100), (100, 0), (150, 0)]
# [66, 67, 74, 75, 76, 77, 80, 81]
# 8
# 8
# 7
# 8
# 7
# 6
# 8
# 6
# 1
# 8
# 5
# 0
# 8
# 4
# 2
# 8
# 3
# 2
# 8
# 2
# 0
# 8
# 1
# 0
# 8
# 0
# [(0, 200)]
# [82]
# 8
# 1
# [(0, 200), (50, 200)]
# [82, 83]
# 8
# 2
# [(0, 200), (50, 200), (100, 200)]
# [82, 83, 84]
# 8
# 3
# 2
# 8
# 2
# [(0, 200), (50, 200), (150, 200)]
# [82, 83, 85]
# 8
# 3
# [(0, 200), (50, 200), (150, 200), (100, 200)]
# [82, 83, 85, 86]
# 8
# 4
# [(0, 200), (50, 200), (150, 200), (100, 200), (200, 200)]
# [82, 83, 85, 86, 87]
# 8
# 5
# [(0, 200), (50, 200), (150, 200), (100, 200), (200, 200), (250, 200)]
# [82, 83, 85, 86, 87, 88]
# 8
# 6
# [(0, 200), (50, 200), (150, 200), (100, 200), (200, 200), (250, 200), (300, 200)]
# [82, 83, 85, 86, 87, 88, 89]
# 8
# 7
# [(0, 200), (50, 200), (150, 200), (100, 200), (200, 200), (250, 200), (300, 200), (350, 200)]
# [82, 83, 85, 86, 87, 88, 89, 90]
# 8
# 8
# 8
# 8
# 8
# 8
# 7
# 8
# 7
# 6
# 8
# 6
# 5
# 8
# 5
# 4
# 8
# 4
# 2
# 8
# 3
# 2
# 8
# 2
# 1
# 8
# 1
# 0
# 8
# 0
# [(250, 100)]
# [91]
