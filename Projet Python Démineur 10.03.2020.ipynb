# %%
from random import *
from tkinter import*
def afficher(M):
    "Affiche une matrice en respectant les alignements par colonnes"
    w=[max([len(str(M[i][j])) for i in range(len(M))]) for j in range(len(M[0]))]
    for i in range(len(M)):
        for j in range(len(M[0])):
            print("%*s" %(w[j],str(M[i][j])), end= ' ')
        print()    

def voisins(n, i, j):
    """Dans une grille n x n, indices (ligne, colonne) des voisins 
    dans la grille d'un sommet (i,j) de la grille"""
    return [(a,b) for (a, b) in [(i,j+1),(i,j-1),(i+1,j),(i-1,j),(i+1,j+1),(i+1,j-1),(i-1,j+1),(i-1,j-1)] if a in range(n) and b in range(n)]

def bomb(L,n,l,c):
    vbomb=voisins(n,l,c)#liste des voisions d'une bombe
    print(vbomb)
    vbomb_len=len(vbomb)
    for i in range(len(L)):
        for j in range(len(L[0])):
            for (a, b) in vbomb:
                if (a,b)==(i,j): #parcours les coordonées de L et les compare avec celle dans vbomb et si elles sont egale
                    x=L[i][j]    #x =x+1
                    if x!=9:
                        x=x+1
                    L[i][j]=x
            
        
L=[[],[],[],[],[],[],[],[]]
s=0
b=11 #nombre de bombe
for i in range (len(L)):
    for j in range (8):
         L[i].append(0)

for p in range (b):
    l=randrange(8)
    c=randrange(8)
    L[l][c]=9
    bomb(L,n,l,c)
    
afficher(L)








WIDTH=500
HEIGHT=500
root=Tk()
unit=50


cnv = Canvas(root, width=unit*n, height=unit*n, background="ivory") 
cnv.pack(padx=10, pady=10, side=LEFT)



def jeu(event):   # quand on cliqe sur une case ça renvoit les coordonées correspondant à la liste L
    y=event.x//50
    x=event.y//50
    print(x,y)
    C=(x,y)
    if L[x][y]!=9:
        print("pas bombe")
    else:
        print("bombe !")
        for i in range(len(L)):
            for j in range(len(L[0])):
                if L[i][j]==9:
                    a=j*50
                    b=i*50
                    cnv.create_oval((10+a,10+b,a+40,b+40),fill='black',width=3,outline="black") # montre toute les bombe quand on clic sur UNE bombe
                    
        
        
def flag (event):
    y=event.x//50
    x=event.y//50
    nbr_clic=0
    a=y*50
    b=x*50
    f=n
    
    cnv.create_oval((10+a,10+b,a+40,b+40),fill='red',width=3,outline="red")
        


def init(): # initialise les case du jeu.
    for line in range(n):
        for col in range(n):
            A=(unit*col, unit*line)
            B=(unit*(col+1), unit*(line+1))
               
            cnv.create_rectangle(A, B, fill="grey",)
            

    
            

cnv.bind("<Button-1>",jeu)
cnv.bind("<Button-3>",flag)         

   
                
init()
root.mainloop()
# Out:
# [(2, 6), (3, 7), (1, 7), (3, 6), (1, 6)]
# [(7, 7), (7, 5), (6, 6), (6, 7), (6, 5)]
# [(5, 4), (5, 2), (6, 3), (4, 3), (6, 4), (6, 2), (4, 4), (4, 2)]
# [(5, 5), (5, 3), (6, 4), (4, 4), (6, 5), (6, 3), (4, 5), (4, 3)]
# [(6, 1), (7, 0), (5, 0), (7, 1), (5, 1)]
# [(4, 5), (4, 3), (5, 4), (3, 4), (5, 5), (5, 3), (3, 5), (3, 3)]
# [(6, 4), (6, 2), (7, 3), (5, 3), (7, 4), (7, 2), (5, 4), (5, 2)]
# [(1, 5), (1, 3), (2, 4), (0, 4), (2, 5), (2, 3), (0, 5), (0, 3)]
# [(7, 6), (6, 7), (6, 6)]
# [(1, 1), (2, 0), (0, 0), (2, 1), (0, 1)]
# [(3, 7), (3, 5), (4, 6), (2, 6), (4, 7), (4, 5), (2, 7), (2, 5)]
# 1 1 0 1 1 1 0 0
# 9 1 0 1 9 1 1 1
# 1 1 0 1 1 2 2 9
# 0 0 0 1 1 2 9 2
# 0 0 1 3 9 3 1 1
# 1 1 2 9 9 2 0 0
# 9 1 2 9 3 2 2 2
# 1 1 1 1 1 1 9 9
# 2 7
# bombe !
